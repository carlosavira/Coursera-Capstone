# %% [markdown]
# # Coursera Capstone Project

# %% [markdown]
# This is fulfilment of coursera course and will be mainly used for capstone project

# %%
#scientific library
import pandas as pd
import numpy as np

# %%
#web scraping library
import requests
from bs4 import BeautifulSoup
import time

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
#create a get request to a URL
r = requests.get('https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Toronto')

# %%
#extract content
c = r.content

# %%
# Create a soup object
soup = BeautifulSoup(c, 'lxml')

# %%
# Find the element on the webpage
main_content = soup.find('table', attrs = {'class': 'wikitable'})

# %%
# Extract the relevant information 
content = main_content.find_all('a')

# %%
#empty list
cc = []

#loop through the content and get value of title attribute
for i in content: 
    cc.append(i['title'])

# %% [markdown]
# **NOTES** :
# I used https://geocode.localfocus.nl/ to get coordinate values of cc (neighborhood scraped from wikipedia). The list values is copied and pasted to the website. Locations from cc shows multiple values of coordinates, for this project, the first occurence of suggested coordinates is chosen. The result of my query is downloaded and available at https://tinyurl.com/yyd4t85l

# %%
df = pd.read_csv('https://tinyurl.com/yyd4t85l')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-190-a8934222142a> in <module>()
# ----> 1 df = pd.read_csv('https://tinyurl.com/yyd4t85l')
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 3, saw 2

# %%
#convert list(cc) to data frame
df = pd.DataFrame(cc)

# %%
#change column name
df.columns = ['Neighborhood']

# %%
#location=geolocator.geocode(df['Neighborhood'])

# %%
df
# Out:
#                            Neighborhood
# 0                      Downtown Toronto
# 1                Harbourfront (Toronto)
# 2                 Little Italy, Toronto
# 3              Little Portugal, Toronto
# 4                             The Annex
# 5                    Yorkville, Toronto
# 6                   South Hill, Toronto
# 7                   Summerhill, Toronto
# 8                         Wychwood Park
# 9                    Deer Park, Toronto
# 10                 Forest Hill, Toronto
# 11                      Oakwood–Vaughan
# 12                   Humewood–Cedarvale
# 13               Corso Italia (Toronto)
# 14                Bedford Park, Toronto
# 15                       Lawrence Manor
# 16                        North Toronto
# 17                 Forest Hill, Toronto
# 18                           North York
# 19                Clanton Park, Toronto
# 20                       Bathurst Manor
# 21                  Willowdale, Toronto
# 22                          Newtonbrook
# 23                  Westminster–Branson
# 24                     Lansing, Toronto
# 25                 Cabbagetown, Toronto
# 26                  St. Lawrence Market
# 27                   Toronto waterfront
# 28                            Moss Park
# 29                 Church and Wellesley
# 30             Garden District, Toronto
# 31                  Moore Park, Toronto
# 32                    Rosedale, Toronto
# 33                   Davisville Village
# 34                      Midtown Toronto
# 35               Lawrence Park, Toronto
# 36                              Leaside
# 37                     Thorncliffe Park
# 38                      Flemingdon Park
# 39                            Don Mills
# 40                            Parkwoods
# 41                     Victoria Village
# 42                          Newtonbrook
# 43                  Willowdale, Toronto
# 44                    Hillcrest Village
# 45              Bayview Woods – Steeles
# 46                      Bayview Village
# 47                   Don Valley Village
# 48                           Henry Farm
# 49               Pleasant View, Toronto
# 50                   Riverdale, Toronto
# 51                   Greektown, Toronto
# 52                          Leslieville
# 53                          The Beaches
# 54                        Upper Beaches
# 55                   Greektown, Toronto
# 56                            East York
# 57                      Playter Estates
# 58                        Old East York
# 59                    O'Connor–Parkview
# 60                        Crescent Town
# 61                 Golden Mile, Toronto
# 62                          Dorset Park
# 63                     Wexford, Toronto
# 64                    Maryvale, Toronto
# 65                 Scarborough Junction
# 66                              Ionview
# 67                             Clairlea
# 68              Bayview Woods – Steeles
# 69                           L'Amoreaux
# 70             Tam O'Shanter – Sullivan
# 71                          Birch Cliff
# 72                    Oakridge, Toronto
# 73                    Toronto Hunt Club
# 74                   Cliffside, Toronto
# 75                  Scarborough Village
# 76                           Cliffcrest
# 77                            Guildwood
# 78                        Eglinton East
# 79              Scarborough City Centre
# 80                      Woburn, Toronto
# 81                 Morningside, Toronto
# 82                              Bendale
# 83                       Rouge, Toronto
# 84                  Port Union, Toronto
# 85                   West Hill, Toronto
# 86              Highland Creek, Toronto
# 87                       Rouge, Toronto
# 88                     Malvern, Toronto
# 89                            High Park
# 90                    Parkdale, Toronto
# 91                     Swansea, Toronto
# 92                Roncesvalles, Toronto
# 93                   Bloor West Village
# 94                           Baby Point
# 95                         The Junction
# 96                      High Park North
# 97                 Silverthorn, Toronto
# 98                        Eglinton West
# 99                    Rockcliffe–Smythe
# 100                    Carleton Village
# 101              Corso Italia (Toronto)
# 102                       York, Toronto
# 103                  Glen Park, Toronto
# 104                   Amesbury, Toronto
# 105              Pelmo Park – Humberlea
# 106                     Weston, Toronto
# 107                   Fairbank, Toronto
# 108                 Maple Leaf, Toronto
# 109                        Mount Dennis
# 110                           Downsview
# 111                       Humber Summit
# 112                          Humbermede
# 113                      Jane and Finch
# 114             York University Heights
# 115                         New Toronto
# 116                Long Branch, Toronto
# 117                              Mimico
# 118                  Alderwood, Toronto
# 119          The Queensway – Humber Bay
# 120                        The Kingsway
# 121                           Etobicoke
# 122  Eringate – Centennial – West Deane
# 123                    Princess Gardens
# 124               Humber Valley Village
# 125          Islington–City Centre West
# 126                       Markland Wood
# 127                   Kingsview Village
# 128                   Richview, Toronto
# 129          Humber Heights – Westmount
# 130                             Rexdale
# 131                 Clairville, Toronto
# 132                         Thistletown
# 133                 Smithfield, Toronto
# 134                   The Elms, Toronto
